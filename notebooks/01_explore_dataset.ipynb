# %%
# !pip install vlrdevapi

# %%
METADATA_PATH = "D:\\Personal Project\\Road2AI_Apple_Pie\\Road2AI_ApplePie\\vietnamese-legal-rag\\data\\metadata.jsonl"
REL_PATH = "D:\\Personal Project\\Road2AI_Apple_Pie\\Road2AI_ApplePie\\vietnamese-legal-rag\\data\\relationships.jsonl"
CONTENT_PATH = "D:\\Personal Project\\Road2AI_Apple_Pie\\Road2AI_ApplePie\\vietnamese-legal-rag\\data\\content.jsonl"

# %%
# !python ../scripts/preprocess.py --metadata "{METADATA_PATH}" --content "{CONTENT_PATH}" --relationships "{REL_PATH}"
# Out:
# Traceback (most recent call last):
#   File "d:\Personal Project\Road2AI_Apple_Pie\Road2AI_ApplePie\vietnamese-legal-rag\scripts\preprocess.py", line 125, in <module>
#     main()
#   File "d:\Personal Project\Road2AI_Apple_Pie\Road2AI_ApplePie\vietnamese-legal-rag\scripts\preprocess.py", line 102, in main
#     joined, content_removals = join_sme_content(filtered, read_table(args.content))
#                                                           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Personal Project\Road2AI_Apple_Pie\Road2AI_ApplePie\vietnamese-legal-rag\scripts\preprocess.py", line 53, in read_table
#     return pd.read_json(path, orient="records", lines=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\conda_env\r2ai\Lib\site-packages\pandas\io\json\_json.py", line 829, in read_json
#     json_reader = JsonReader(
#                   ^^^^^^^^^^^
#   File "d:\conda_env\r2ai\Lib\site-packages\pandas\io\json\_json.py", line 936, in __init__
# ...
